# %%
from pathlib import Path
import pickle
from pprint import pprint
import sys
sys.path.append('..')

import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
import yaml

from scripts import data

# %%
DIR_INPUTS = Path('../../data/inputs')
dir_path = Path.joinpath(DIR_INPUTS, 'csv_files')
DIR_PATH_CONFIGS = Path('../../data/configs/paths.yaml')
PROJECT_PATH = Path('../../data/models/d012-PMAD-groupk-lgbm-cv')

if not PROJECT_PATH.exists():
    PROJECT_PATH.mkdir(parents=True)
    print(f'Create a directory at {PROJECT_PATH}')

COLUMNS_BASE = [
    'case_id',
    'date_decision',
    'MONTH',
    'WEEK_NUM',
    'target',
]
COLUMNS_BASE_TEST = [
    'case_id',
    'date_decision',
    'MONTH',
    'WEEK_NUM',
]

with open(DIR_PATH_CONFIGS, 'r') as f:
    dict_tables_all = yaml.safe_load(f)

pprint(dict_tables_all)
# Out:
# {0: {'static': ['static_0_0.csv', 'static_0_1.csv'],
#      'static_cb': ['static_cb_0.csv']},
#  1: {'applprev': ['applprev_1_0.csv', 'applprev_1_1.csv'],
#      'credit_bureau_a': ['credit_bureau_a_1_0.csv',
#                          'credit_bureau_a_1_1.csv',
#                          'credit_bureau_a_1_2.csv',
#                          'credit_bureau_a_1_3.csv'],
#      'credit_bureau_b': ['credit_bureau_b_1.csv'],
#      'debitcard': ['debitcard_1.csv'],
#      'deposit': ['deposit_1.csv'],
#      'other': ['other_1.csv'],
#      'person': ['person_1.csv'],
#      'tax_registry_a': ['tax_registry_a_1.csv'],
#      'tax_registry_b': ['tax_registry_b_1.csv'],
#      'tax_registry_c': ['tax_registry_c_1.csv']},
#  2: {'applprev': ['applprev_2.csv'],
#      'credit_bureau_a': ['credit_bureau_a_2_0.csv',
#                          'credit_bureau_a_2_1.csv',
#                          'credit_bureau_a_2_2.csv',
#                          'credit_bureau_a_2_3.csv',
#                          'credit_bureau_a_2_4.csv',
#                          'credit_bureau_a_2_5.csv',
#                          'credit_bureau_a_2_6.csv',
#                          'credit_bureau_a_2_7.csv',
#                          'credit_bureau_a_2_8.csv',
#                          'credit_bureau_a_2_9.csv',
#                          'credit_bureau_a_2_10.csv'],
#      'credit_bureau_b': ['credit_bureau_b_2.csv'],
#      'person': ['person_2.csv']},
#  'base': ['base.csv']}

# %%
dict_tabels_use = {
    0: list(dict_tables_all[0].keys()),
    1: list(dict_tables_all[1].keys()),
    2: list(dict_tables_all[2].keys()),
}
category_columns_use = ['P', 'M', 'A', 'D']

pprint(dict_tabels_use)
# Out:
# {0: ['static', 'static_cb'],
#  1: ['applprev',
#      'credit_bureau_a',
#      'credit_bureau_b',
#      'debitcard',
#      'deposit',
#      'other',
#      'person',
#      'tax_registry_a',
#      'tax_registry_b',
#      'tax_registry_c'],
#  2: ['applprev', 'credit_bureau_a', 'credit_bureau_b', 'person']}

# %%
df_train_merger = data.DataFrameMerger(dict_tables_all, dict_tabels_use, category_columns_use, dir_path)
df_base_train, dict_df_train = df_train_merger.load_concat('train')
dict_df_train = df_train_merger.aggregate(dict_df_train)
df_train = df_train_merger.merge(df_base_train, dict_df_train)
# Out:
# base (1526659, 5)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (20,45,46,53,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (20,45,46,56,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# static (1526659, 77)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (1,2,3,4,7,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# static_cb (1500476, 19)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# applprev (1221522, 28)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (11,12,14,30,44,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# credit_bureau_a (1386273, 50)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# credit_bureau_b (36500, 33)
# debitcard (111772, 5)
# deposit (105111, 4)
# other (51109, 6)
# /home/oxyut/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# person (1526659, 13)
# tax_registry_a (457934, 4)
# tax_registry_b (150732, 4)
# tax_registry_c (482265, 4)
# applprev (1221522, 2)
# credit_bureau_a (1385288, 11)
# credit_bureau_b (36446, 4)
# person (1435041, 7)

# %%
# df_train.to_parquet('../../data/processed/train-d012.parquet')
df_train = pd.read_parquet('../../data/processed/train-d012.parquet')

display(df_train)
# Out:
#          case_id date_decision   MONTH  WEEK_NUM  target  \
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
#          actualdpdtolerance_344P  avgdbddpdlast24m_3658932P  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1526654                      0.0                      -23.0
# 1526655                      0.0                      -18.0
# 1526656                      0.0                      -12.0
# 1526657                      0.0                      -33.0
# 1526658                      0.0                       -6.0
#
#          avgdbddpdlast3m_4187120P  avgdbdtollast24m_4525197P  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1526654                     -43.0                      -23.0
# 1526655                     -12.0                      -18.0
# 1526656                       NaN                      -16.0
# 1526657                     -64.0                      -34.0
# 1526658                      -5.0                       -6.0
#
#          avgdpdtolclosure24_3658938P  ...  2_pmts_overdue_1152A  \
# 0                                NaN  ...                   NaN
# 1                                NaN  ...                   NaN
# 2                                NaN  ...                   NaN
# 3                                NaN  ...                   NaN
# 4                                NaN  ...                   NaN
# ...                              ...  ...                   ...
# 1526654                          0.0  ...                   NaN
# 1526655                          0.0  ...                   NaN
# 1526656                          1.0  ...                   NaN
# 1526657                          0.0  ...                   NaN
# 1526658                          0.0  ...                   NaN
#
#          2_pmts_dpdvalue_108P  2_pmts_pmtsoverdue_635A  2_pmts_date_1107D  \
# 0                         NaN                      NaN               None
# 1                         NaN                      NaN               None
# 2                         NaN                      NaN               None
# 3                         NaN                      NaN               None
# 4                         NaN                      NaN               None
# ...                       ...                      ...                ...
# 1526654                   NaN                      NaN               None
# 1526655                   NaN                      NaN               None
# 1526656                   NaN                      NaN               None
# 1526657                   NaN                      NaN               None
# 1526658                   NaN                      NaN               None
#
#          2_addres_district_368M  2_addres_zip_823M  2_conts_role_79M  \
# 0                          None               None              None
# 1                          None               None              None
# 2                          None               None              None
# 3                          None               None              None
# 4                          None               None              None
# ...                         ...                ...               ...
# 1526654                a55475b1           a55475b1          a55475b1
# 1526655                a55475b1           a55475b1          a55475b1
# 1526656                a55475b1           a55475b1          a55475b1
# 1526657                a55475b1           a55475b1          a55475b1
# 1526658                a55475b1           a55475b1          a55475b1
#
#          2_empls_economicalst_849M  2_empls_employer_name_740M  \
# 0                             None                        None
# 1                             None                        None
# 2                             None                        None
# 3                             None                        None
# 4                             None                        None
# ...                            ...                         ...
# 1526654                   a55475b1                    a55475b1
# 1526655                   a55475b1                    a55475b1
# 1526656                   a55475b1                    a55475b1
# 1526657                   a55475b1                    a55475b1
# 1526658                   a55475b1                    a55475b1
#
#          2_empls_employedfrom_796D
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ...                            ...
# 1526654                       None
# 1526655                       None
# 1526656                       None
# 1526657                       None
# 1526658                       None
#
# [1526659 rows x 260 columns]

# %%
dict_columns = {0:[], 1:[], 2:[]}
for k in df_train.columns:
    if k.startswith('2_'):
        dict_columns[2].append(k)
    elif k.startswith('1_'):
        dict_columns[1].append(k)
    else:
        dict_columns[0].append(k)

for k, v in dict_columns.items():
    print(k, len(v))
# Out:
# 0 99
# 1 141
# 2 20

# %%
df_train_processed = data.preprocess(df_train, category_columns_use, mode='train')
y = df_train_processed[COLUMNS_BASE]
X = df_train_processed.drop(columns=COLUMNS_BASE)

# %%
display(X)
display(X.dtypes)
display(y)
# Out:
#          actualdpdtolerance_344P  avgdbddpdlast24m_3658932P  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1526654                      0.0                      -23.0
# 1526655                      0.0                      -18.0
# 1526656                      0.0                      -12.0
# 1526657                      0.0                      -33.0
# 1526658                      0.0                       -6.0
#
#          avgdbddpdlast3m_4187120P  avgdbdtollast24m_4525197P  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1526654                     -43.0                      -23.0
# 1526655                     -12.0                      -18.0
# 1526656                       NaN                      -16.0
# 1526657                     -64.0                      -34.0
# 1526658                      -5.0                       -6.0
#
#          avgdpdtolclosure24_3658938P  avgmaxdpdlast9m_3716943P  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# ...                              ...                       ...
# 1526654                          0.0                       0.0
# 1526655                          0.0                       0.0
# 1526656                          1.0                       NaN
# 1526657                          0.0                       0.0
# 1526658                          0.0                       0.0
#
#          maxdbddpdlast1m_3658939P  maxdbddpdtollast12m_3658940P  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 1526654                       0.0                           0.0
# 1526655                       0.0                           2.0
# 1526656                       NaN                         -27.0
# 1526657                     -66.0                           0.0
# 1526658                      -5.0                          -2.0
#
#          maxdbddpdtollast6m_4187119P  maxdpdfrom6mto36m_3546853P  ...  \
# 0                                NaN                         0.0  ...
# 1                                NaN                         0.0  ...
# 2                                NaN                         NaN  ...
# 3                                NaN                         0.0  ...
# 4                                NaN                         0.0  ...
# ...                              ...                         ...  ...
# 1526654                          0.0                         0.0  ...
# 1526655                          2.0                         0.0  ...
# 1526656                          NaN                         4.0  ...
# 1526657                        -33.0                         2.0  ...
# 1526658                         -2.0                         1.0  ...
#
#          1_processingdate_168D_day  1_processingdate_168D_weekday  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 1526654                        NaN                            NaN
# 1526655                        NaN                            NaN
# 1526656                        NaN                            NaN
# 1526657                        NaN                            NaN
# 1526658                        NaN                            NaN
#
#          2_pmts_date_1107D_year  2_pmts_date_1107D_month  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 1526654                     NaN                      NaN
# 1526655                     NaN                      NaN
# 1526656                     NaN                      NaN
# 1526657                     NaN                      NaN
# 1526658                     NaN                      NaN
#
#          2_pmts_date_1107D_day  2_pmts_date_1107D_weekday  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 1526654                    NaN                        NaN
# 1526655                    NaN                        NaN
# 1526656                    NaN                        NaN
# 1526657                    NaN                        NaN
# 1526658                    NaN                        NaN
#
#          2_empls_employedfrom_796D_year  2_empls_employedfrom_796D_month  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 1526654                             NaN                              NaN
# 1526655                             NaN                              NaN
# 1526656                             NaN                              NaN
# 1526657                             NaN                              NaN
# 1526658                             NaN                              NaN
#
#          2_empls_employedfrom_796D_day  2_empls_employedfrom_796D_weekday
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ...                                ...                                ...
# 1526654                            NaN                                NaN
# 1526655                            NaN                                NaN
# 1526656                            NaN                                NaN
# 1526657                            NaN                                NaN
# 1526658                            NaN                                NaN
#
# [1526659 rows x 426 columns]
# actualdpdtolerance_344P              float64
# avgdbddpdlast24m_3658932P            float64
# avgdbddpdlast3m_4187120P             float64
# avgdbdtollast24m_4525197P            float64
# avgdpdtolclosure24_3658938P          float64
#                                       ...
# 2_pmts_date_1107D_weekday            float64
# 2_empls_employedfrom_796D_year       float64
# 2_empls_employedfrom_796D_month      float64
# 2_empls_employedfrom_796D_day        float64
# 2_empls_employedfrom_796D_weekday    float64
# Length: 426, dtype: object
#          case_id date_decision   MONTH  WEEK_NUM  target
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
# [1526659 rows x 5 columns]

# %%
X.to_parquet(Path.joinpath(PROJECT_PATH, 'X.parquet'))
y.to_parquet(Path.joinpath(PROJECT_PATH, 'y.parquet'))

# %%
X = pd.read_parquet(Path.joinpath(PROJECT_PATH, 'X.parquet'))
y = pd.read_parquet(Path.joinpath(PROJECT_PATH, 'y.parquet'))

# %%
print(X.shape, y.shape)
# Out:
# (1526659, 426) (1526659, 5)

# %%
params = {
    'objective': 'binary',
    'metric': ['binary_logoss', 'auc', 'average_precision'],
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'seed': 42,
    'max_depth': 5,
    'num_leaves': 31,
}

# %%
# skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
skf = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=42)
models = []
y_preds_valid = []
idx_valid = []
for n, (train_index, valid_index) in enumerate(skf.split(X, y['target'], groups=y['WEEK_NUM'])):
    print(f'Fold {n+1}')
    dataset_train = lgb.Dataset(X.iloc[train_index], y.iloc[train_index]['target'])
    dataset_valid = lgb.Dataset(X.iloc[valid_index], y.iloc[valid_index]['target'])
    print(f'Train: {len(train_index)}, Valid: {len(valid_index)}')
    
    model = lgb.train(
        params,
        dataset_train,
        num_boost_round=100_000,
        valid_sets=[dataset_train, dataset_valid],
        callbacks=[
            lgb.early_stopping(100, first_metric_only=True),
            lgb.log_evaluation(100),
        ],
    )
    models.append(model)
    y_pred_valid = model.predict(X.iloc[valid_index])
    y_preds_valid.append(y_pred_valid)
    idx_valid.append(valid_index)

y_preds_valid = np.concatenate(y_preds_valid)
idx_valid = np.concatenate(idx_valid)
# Out:
# Fold 1
# Train: 1202502, Valid: 324157
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.837262	training's average_precision: 0.185198	valid_1's auc: 0.830014	valid_1's average_precision: 0.164351
# [200]	training's auc: 0.853385	training's average_precision: 0.218305	valid_1's auc: 0.834836	valid_1's average_precision: 0.169898
# [300]	training's auc: 0.864149	training's average_precision: 0.248856	valid_1's auc: 0.836979	valid_1's average_precision: 0.17222
# [400]	training's auc: 0.8733	training's average_precision: 0.278253	valid_1's auc: 0.837764	valid_1's average_precision: 0.172871
# [500]	training's auc: 0.881428	training's average_precision: 0.308458	valid_1's auc: 0.837931	valid_1's average_precision: 0.172696
# [600]	training's auc: 0.888717	training's average_precision: 0.336882	valid_1's auc: 0.838165	valid_1's average_precision: 0.173108
# [700]	training's auc: 0.895108	training's average_precision: 0.363743	valid_1's auc: 0.838103	valid_1's average_precision: 0.173404
# Early stopping, best iteration is:
# [646]	training's auc: 0.891644	training's average_precision: 0.349672	valid_1's auc: 0.838231	valid_1's average_precision: 0.173208
# Evaluated only: auc
# Fold 2
# Train: 1201472, Valid: 325187
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.839182	training's average_precision: 0.192465	valid_1's auc: 0.818327	valid_1's average_precision: 0.138564
# [200]	training's auc: 0.855437	training's average_precision: 0.22633	valid_1's auc: 0.824379	valid_1's average_precision: 0.143452
# [300]	training's auc: 0.866078	training's average_precision: 0.256742	valid_1's auc: 0.826656	valid_1's average_precision: 0.144935
# [400]	training's auc: 0.87526	training's average_precision: 0.285658	valid_1's auc: 0.828136	valid_1's average_precision: 0.145895
# [500]	training's auc: 0.883176	training's average_precision: 0.31427	valid_1's auc: 0.829102	valid_1's average_precision: 0.146588
# [600]	training's auc: 0.889784	training's average_precision: 0.341484	valid_1's auc: 0.829463	valid_1's average_precision: 0.146675
# [700]	training's auc: 0.8959	training's average_precision: 0.367867	valid_1's auc: 0.829847	valid_1's average_precision: 0.146963
# [800]	training's auc: 0.901784	training's average_precision: 0.393489	valid_1's auc: 0.829974	valid_1's average_precision: 0.146925
# [900]	training's auc: 0.906936	training's average_precision: 0.418981	valid_1's auc: 0.829671	valid_1's average_precision: 0.14647
# Early stopping, best iteration is:
# [819]	training's auc: 0.902651	training's average_precision: 0.398458	valid_1's auc: 0.830063	valid_1's average_precision: 0.146826
# Evaluated only: auc
# Fold 3
# Train: 1229154, Valid: 297505
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.839397	training's average_precision: 0.184894	valid_1's auc: 0.819374	valid_1's average_precision: 0.157232
# [200]	training's auc: 0.855833	training's average_precision: 0.21965	valid_1's auc: 0.824811	valid_1's average_precision: 0.163366
# [300]	training's auc: 0.866623	training's average_precision: 0.249304	valid_1's auc: 0.826811	valid_1's average_precision: 0.166074
# [400]	training's auc: 0.875644	training's average_precision: 0.278818	valid_1's auc: 0.827963	valid_1's average_precision: 0.167268
# [500]	training's auc: 0.88306	training's average_precision: 0.306851	valid_1's auc: 0.828722	valid_1's average_precision: 0.167381
# [600]	training's auc: 0.89045	training's average_precision: 0.334655	valid_1's auc: 0.828993	valid_1's average_precision: 0.167617
# [700]	training's auc: 0.896918	training's average_precision: 0.362356	valid_1's auc: 0.829168	valid_1's average_precision: 0.167634
# [800]	training's auc: 0.90245	training's average_precision: 0.388587	valid_1's auc: 0.829402	valid_1's average_precision: 0.16798
# [900]	training's auc: 0.907492	training's average_precision: 0.413462	valid_1's auc: 0.829264	valid_1's average_precision: 0.168176
# Early stopping, best iteration is:
# [812]	training's auc: 0.9031	training's average_precision: 0.392024	valid_1's auc: 0.829455	valid_1's average_precision: 0.168071
# Evaluated only: auc
# Fold 4
# Train: 1278541, Valid: 248118
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.838496	training's average_precision: 0.189542	valid_1's auc: 0.820522	valid_1's average_precision: 0.137495
# [200]	training's auc: 0.854234	training's average_precision: 0.222323	valid_1's auc: 0.82623	valid_1's average_precision: 0.142037
# [300]	training's auc: 0.864958	training's average_precision: 0.251272	valid_1's auc: 0.828459	valid_1's average_precision: 0.143844
# [400]	training's auc: 0.873703	training's average_precision: 0.278185	valid_1's auc: 0.82919	valid_1's average_precision: 0.144825
# [500]	training's auc: 0.881028	training's average_precision: 0.305042	valid_1's auc: 0.829903	valid_1's average_precision: 0.145685
# [600]	training's auc: 0.887602	training's average_precision: 0.33046	valid_1's auc: 0.830238	valid_1's average_precision: 0.145972
# [700]	training's auc: 0.893908	training's average_precision: 0.355358	valid_1's auc: 0.830401	valid_1's average_precision: 0.146369
# Early stopping, best iteration is:
# [652]	training's auc: 0.890694	training's average_precision: 0.342991	valid_1's auc: 0.830606	valid_1's average_precision: 0.146239
# Evaluated only: auc
# Fold 5
# Train: 1194967, Valid: 331692
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.840664	training's average_precision: 0.186841	valid_1's auc: 0.81593	valid_1's average_precision: 0.15592
# [200]	training's auc: 0.857146	training's average_precision: 0.222236	valid_1's auc: 0.821506	valid_1's average_precision: 0.161602
# [300]	training's auc: 0.868578	training's average_precision: 0.255014	valid_1's auc: 0.823503	valid_1's average_precision: 0.16309
# [400]	training's auc: 0.877529	training's average_precision: 0.284168	valid_1's auc: 0.824174	valid_1's average_precision: 0.163451
# Early stopping, best iteration is:
# [374]	training's auc: 0.875576	training's average_precision: 0.277318	valid_1's auc: 0.824403	valid_1's average_precision: 0.163908
# Evaluated only: auc

# %%
for i, model in enumerate(models):
    with open(Path.joinpath(PROJECT_PATH, f'model_{i}.pkl'), 'wb') as f:
        pickle.dump(model, f)

# save y_preds_valid
np.save(Path.joinpath(PROJECT_PATH, 'y_preds_valid.npy'), y_preds_valid)
np.save(Path.joinpath(PROJECT_PATH, 'idx_valid.npy'), idx_valid)

# %%
evaluator = data.Evaluator(y.iloc[idx_valid], y_preds_valid, save_path=PROJECT_PATH)

evaluator.plot_pred(is_log=True)
evaluator.plot_roc()
df_gini_weeks, stability = evaluator.plot_gini()
# Out:
# 0.6372792223661403
