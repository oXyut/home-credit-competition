# %%
from pathlib import Path
import pickle
from pprint import pprint
import sys
sys.path.append('..')

import lightgbm as lgb
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
import yaml

from scripts import data

# %%
DIR_INPUTS = Path('../../data/inputs')
dir_path = Path.joinpath(DIR_INPUTS, 'csv_files')
DIR_PATH_CONFIGS = Path('../../data/configs/paths.yaml')
PROJECT_PATH = Path('../../data/models/d012-PMAD-lgbm-cv')

if not PROJECT_PATH.exists():
    PROJECT_PATH.mkdir(parents=True)
    print(f'Create a directory at {PROJECT_PATH}')

COLUMNS_BASE = [
    'case_id',
    'date_decision',
    'MONTH',
    'WEEK_NUM',
    'target',
]
COLUMNS_BASE_TEST = [
    'case_id',
    'date_decision',
    'MONTH',
    'WEEK_NUM',
]

with open(DIR_PATH_CONFIGS, 'r') as f:
    dict_tables_all = yaml.safe_load(f)

pprint(dict_tables_all)
# Out:
# Create a directory at ../../data/models/d012-PMAD-lgbm-cv
# {0: {'static': ['static_0_0.csv', 'static_0_1.csv'],
#      'static_cb': ['static_cb_0.csv']},
#  1: {'applprev': ['applprev_1_0.csv', 'applprev_1_1.csv'],
#      'credit_bureau_a': ['credit_bureau_a_1_0.csv',
#                          'credit_bureau_a_1_1.csv',
#                          'credit_bureau_a_1_2.csv',
#                          'credit_bureau_a_1_3.csv'],
#      'credit_bureau_b': ['credit_bureau_b_1.csv'],
#      'debitcard': ['debitcard_1.csv'],
#      'deposit': ['deposit_1.csv'],
#      'other': ['other_1.csv'],
#      'person': ['person_1.csv'],
#      'tax_registry_a': ['tax_registry_a_1.csv'],
#      'tax_registry_b': ['tax_registry_b_1.csv'],
#      'tax_registry_c': ['tax_registry_c_1.csv']},
#  2: {'applprev': ['applprev_2.csv'],
#      'credit_bureau_a': ['credit_bureau_a_2_0.csv',
#                          'credit_bureau_a_2_1.csv',
#                          'credit_bureau_a_2_2.csv',
#                          'credit_bureau_a_2_3.csv',
#                          'credit_bureau_a_2_4.csv',
#                          'credit_bureau_a_2_5.csv',
#                          'credit_bureau_a_2_6.csv',
#                          'credit_bureau_a_2_7.csv',
#                          'credit_bureau_a_2_8.csv',
#                          'credit_bureau_a_2_9.csv',
#                          'credit_bureau_a_2_10.csv'],
#      'credit_bureau_b': ['credit_bureau_b_2.csv'],
#      'person': ['person_2.csv']},
#  'base': ['base.csv']}

# %%
dict_tabels_use = {
    0: list(dict_tables_all[0].keys()),
    1: list(dict_tables_all[1].keys()),
    2: list(dict_tables_all[2].keys()),
}
category_columns_use = ['P', 'M', 'A', 'D']

pprint(dict_tabels_use)
# Out:
# {0: ['static', 'static_cb'],
#  1: ['applprev',
#      'credit_bureau_a',
#      'credit_bureau_b',
#      'debitcard',
#      'deposit',
#      'other',
#      'person',
#      'tax_registry_a',
#      'tax_registry_b',
#      'tax_registry_c'],
#  2: ['applprev', 'credit_bureau_a', 'credit_bureau_b', 'person']}

# %%
df_train_merger = data.DataFrameMerger(dict_tables_all, dict_tabels_use, category_columns_use, dir_path)
df_base_train, dict_df_train = df_train_merger.load_concat('train')
dict_df_train = df_train_merger.aggregate(dict_df_train)
df_train = df_train_merger.merge(df_base_train, dict_df_train)
# Out:
# base (1526659, 5)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (20,45,46,53,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (20,45,46,56,57,84,143,146,167) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# static (1526659, 77)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (1,2,3,4,7,45,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# static_cb (1500476, 19)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# applprev (1221522, 28)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (11,12,14,30,44,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# credit_bureau_a (1386273, 50)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# credit_bureau_b (36500, 33)
# debitcard (111772, 5)
# deposit (105111, 4)
# other (51109, 6)
# /Users/suzukiyuto/kaggle-works/home-credit-competition/src/notebooks/../scripts/data.py:94: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ = pd.read_csv(Path.joinpath(self.dir_path, mode, f'{mode}_{p}'))
# person (1526659, 13)
# tax_registry_a (457934, 4)
# tax_registry_b (150732, 4)
# tax_registry_c (482265, 4)
# applprev (1221522, 2)
# credit_bureau_a (1385288, 11)
# credit_bureau_b (36446, 4)
# person (1435041, 7)

# %%
# df_train.to_parquet('../../data/processed/train-d012.parquet')
df_train = pd.read_parquet('../../data/processed/train-d012.parquet')

display(df_train)
# Out:
#          case_id date_decision   MONTH  WEEK_NUM  target  \
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
#          actualdpdtolerance_344P  avgdbddpdlast24m_3658932P  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1526654                      0.0                      -23.0
# 1526655                      0.0                      -18.0
# 1526656                      0.0                      -12.0
# 1526657                      0.0                      -33.0
# 1526658                      0.0                       -6.0
#
#          avgdbddpdlast3m_4187120P  avgdbdtollast24m_4525197P  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1526654                     -43.0                      -23.0
# 1526655                     -12.0                      -18.0
# 1526656                       NaN                      -16.0
# 1526657                     -64.0                      -34.0
# 1526658                      -5.0                       -6.0
#
#          avgdpdtolclosure24_3658938P  ...  2_pmts_overdue_1152A  \
# 0                                NaN  ...                   NaN
# 1                                NaN  ...                   NaN
# 2                                NaN  ...                   NaN
# 3                                NaN  ...                   NaN
# 4                                NaN  ...                   NaN
# ...                              ...  ...                   ...
# 1526654                          0.0  ...                   NaN
# 1526655                          0.0  ...                   NaN
# 1526656                          1.0  ...                   NaN
# 1526657                          0.0  ...                   NaN
# 1526658                          0.0  ...                   NaN
#
#          2_pmts_dpdvalue_108P  2_pmts_pmtsoverdue_635A  2_pmts_date_1107D  \
# 0                         NaN                      NaN               None
# 1                         NaN                      NaN               None
# 2                         NaN                      NaN               None
# 3                         NaN                      NaN               None
# 4                         NaN                      NaN               None
# ...                       ...                      ...                ...
# 1526654                   NaN                      NaN               None
# 1526655                   NaN                      NaN               None
# 1526656                   NaN                      NaN               None
# 1526657                   NaN                      NaN               None
# 1526658                   NaN                      NaN               None
#
#          2_addres_district_368M  2_addres_zip_823M  2_conts_role_79M  \
# 0                          None               None              None
# 1                          None               None              None
# 2                          None               None              None
# 3                          None               None              None
# 4                          None               None              None
# ...                         ...                ...               ...
# 1526654                a55475b1           a55475b1          a55475b1
# 1526655                a55475b1           a55475b1          a55475b1
# 1526656                a55475b1           a55475b1          a55475b1
# 1526657                a55475b1           a55475b1          a55475b1
# 1526658                a55475b1           a55475b1          a55475b1
#
#          2_empls_economicalst_849M  2_empls_employer_name_740M  \
# 0                             None                        None
# 1                             None                        None
# 2                             None                        None
# 3                             None                        None
# 4                             None                        None
# ...                            ...                         ...
# 1526654                   a55475b1                    a55475b1
# 1526655                   a55475b1                    a55475b1
# 1526656                   a55475b1                    a55475b1
# 1526657                   a55475b1                    a55475b1
# 1526658                   a55475b1                    a55475b1
#
#          2_empls_employedfrom_796D
# 0                             None
# 1                             None
# 2                             None
# 3                             None
# 4                             None
# ...                            ...
# 1526654                       None
# 1526655                       None
# 1526656                       None
# 1526657                       None
# 1526658                       None
#
# [1526659 rows x 260 columns]

# %%
dict_columns = {0:[], 1:[], 2:[]}
for k in df_train.columns:
    if k.startswith('2_'):
        dict_columns[2].append(k)
    elif k.startswith('1_'):
        dict_columns[1].append(k)
    else:
        dict_columns[0].append(k)

for k, v in dict_columns.items():
    print(k, len(v))
# Out:
# 0 99
# 1 141
# 2 20

# %%
df_train_processed = data.preprocess(df_train, category_columns_use, mode='train')
y = df_train_processed[COLUMNS_BASE]
X = df_train_processed.drop(columns=COLUMNS_BASE)

# %%
display(X)
display(X.dtypes)
display(y)
# Out:
#          actualdpdtolerance_344P  avgdbddpdlast24m_3658932P  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# 3                            NaN                        NaN
# 4                            NaN                        NaN
# ...                          ...                        ...
# 1526654                      0.0                      -23.0
# 1526655                      0.0                      -18.0
# 1526656                      0.0                      -12.0
# 1526657                      0.0                      -33.0
# 1526658                      0.0                       -6.0
#
#          avgdbddpdlast3m_4187120P  avgdbdtollast24m_4525197P  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 1526654                     -43.0                      -23.0
# 1526655                     -12.0                      -18.0
# 1526656                       NaN                      -16.0
# 1526657                     -64.0                      -34.0
# 1526658                      -5.0                       -6.0
#
#          avgdpdtolclosure24_3658938P  avgmaxdpdlast9m_3716943P  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
# ...                              ...                       ...
# 1526654                          0.0                       0.0
# 1526655                          0.0                       0.0
# 1526656                          1.0                       NaN
# 1526657                          0.0                       0.0
# 1526658                          0.0                       0.0
#
#          maxdbddpdlast1m_3658939P  maxdbddpdtollast12m_3658940P  \
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 1526654                       0.0                           0.0
# 1526655                       0.0                           2.0
# 1526656                       NaN                         -27.0
# 1526657                     -66.0                           0.0
# 1526658                      -5.0                          -2.0
#
#          maxdbddpdtollast6m_4187119P  maxdpdfrom6mto36m_3546853P  ...  \
# 0                                NaN                         0.0  ...
# 1                                NaN                         0.0  ...
# 2                                NaN                         NaN  ...
# 3                                NaN                         0.0  ...
# 4                                NaN                         0.0  ...
# ...                              ...                         ...  ...
# 1526654                          0.0                         0.0  ...
# 1526655                          2.0                         0.0  ...
# 1526656                          NaN                         4.0  ...
# 1526657                        -33.0                         2.0  ...
# 1526658                         -2.0                         1.0  ...
#
#          1_processingdate_168D_day  1_processingdate_168D_weekday  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ...                            ...                            ...
# 1526654                        NaN                            NaN
# 1526655                        NaN                            NaN
# 1526656                        NaN                            NaN
# 1526657                        NaN                            NaN
# 1526658                        NaN                            NaN
#
#          2_pmts_date_1107D_year  2_pmts_date_1107D_month  \
# 0                           NaN                      NaN
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 1526654                     NaN                      NaN
# 1526655                     NaN                      NaN
# 1526656                     NaN                      NaN
# 1526657                     NaN                      NaN
# 1526658                     NaN                      NaN
#
#          2_pmts_date_1107D_day  2_pmts_date_1107D_weekday  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ...                        ...                        ...
# 1526654                    NaN                        NaN
# 1526655                    NaN                        NaN
# 1526656                    NaN                        NaN
# 1526657                    NaN                        NaN
# 1526658                    NaN                        NaN
#
#          2_empls_employedfrom_796D_year  2_empls_employedfrom_796D_month  \
# 0                                   NaN                              NaN
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# ...                                 ...                              ...
# 1526654                             NaN                              NaN
# 1526655                             NaN                              NaN
# 1526656                             NaN                              NaN
# 1526657                             NaN                              NaN
# 1526658                             NaN                              NaN
#
#          2_empls_employedfrom_796D_day  2_empls_employedfrom_796D_weekday
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ...                                ...                                ...
# 1526654                            NaN                                NaN
# 1526655                            NaN                                NaN
# 1526656                            NaN                                NaN
# 1526657                            NaN                                NaN
# 1526658                            NaN                                NaN
#
# [1526659 rows x 426 columns]
# actualdpdtolerance_344P              float64
# avgdbddpdlast24m_3658932P            float64
# avgdbddpdlast3m_4187120P             float64
# avgdbdtollast24m_4525197P            float64
# avgdpdtolclosure24_3658938P          float64
#                                       ...
# 2_pmts_date_1107D_weekday            float64
# 2_empls_employedfrom_796D_year       float64
# 2_empls_employedfrom_796D_month      float64
# 2_empls_employedfrom_796D_day        float64
# 2_empls_employedfrom_796D_weekday    float64
# Length: 426, dtype: object
#          case_id date_decision   MONTH  WEEK_NUM  target
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
# [1526659 rows x 5 columns]

# %%
X.to_parquet(Path.joinpath(PROJECT_PATH, 'X.parquet'))
y.to_parquet(Path.joinpath(PROJECT_PATH, 'y.parquet'))

# %%
X = pd.read_parquet(Path.joinpath(PROJECT_PATH, 'X.parquet'))
y = pd.read_parquet(Path.joinpath(PROJECT_PATH, 'y.parquet'))

# %%
print(X.shape, y.shape)
# Out:
# (1526659, 426) (1526659, 5)

# %%
params = {
    'objective': 'binary',
    'metric': ['binary_logoss', 'auc', 'average_precision'],
    'verbosity': -1,
    'boosting_type': 'gbdt',
    'seed': 42,
    'max_depth': 5,
    'num_leaves': 31,
}

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
models = []
y_preds_valid = []
idx_valid = []
for n, (train_index, valid_index) in enumerate(skf.split(X, y['target'])):
    print(f'Fold {n+1}')
    dataset_train = lgb.Dataset(X.iloc[train_index], y.iloc[train_index]['target'])
    dataset_valid = lgb.Dataset(X.iloc[valid_index], y.iloc[valid_index]['target'])
    print(f'Train: {len(train_index)}, Valid: {len(valid_index)}')
    
    model = lgb.train(
        params,
        dataset_train,
        num_boost_round=100_000,
        valid_sets=[dataset_train, dataset_valid],
        callbacks=[
            lgb.early_stopping(100, first_metric_only=True),
            lgb.log_evaluation(100),
        ],
    )
    models.append(model)
    y_pred_valid = model.predict(X.iloc[valid_index])
    y_preds_valid.append(y_pred_valid)
    idx_valid.append(valid_index)

y_preds_valid = np.concatenate(y_preds_valid)
idx_valid = np.concatenate(idx_valid)
# Out:
# Fold 1
# Train: 1221327, Valid: 305332
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.839323	training's average_precision: 0.189519	valid_1's auc: 0.819577	valid_1's average_precision: 0.150989
# [200]	training's auc: 0.855635	training's average_precision: 0.223347	valid_1's auc: 0.825323	valid_1's average_precision: 0.156455
# [300]	training's auc: 0.866611	training's average_precision: 0.254489	valid_1's auc: 0.827924	valid_1's average_precision: 0.159645
# [400]	training's auc: 0.875642	training's average_precision: 0.283664	valid_1's auc: 0.828947	valid_1's average_precision: 0.161043
# [500]	training's auc: 0.883166	training's average_precision: 0.312435	valid_1's auc: 0.82942	valid_1's average_precision: 0.161595
# [600]	training's auc: 0.890095	training's average_precision: 0.339057	valid_1's auc: 0.829763	valid_1's average_precision: 0.162743
# [700]	training's auc: 0.895974	training's average_precision: 0.365614	valid_1's auc: 0.830005	valid_1's average_precision: 0.163464
# [800]	training's auc: 0.901529	training's average_precision: 0.390326	valid_1's auc: 0.830049	valid_1's average_precision: 0.163891
# Early stopping, best iteration is:
# [749]	training's auc: 0.898761	training's average_precision: 0.377007	valid_1's auc: 0.830165	valid_1's average_precision: 0.163776
# Evaluated only: auc
# Fold 2
# Train: 1221327, Valid: 305332
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.839057	training's average_precision: 0.18756	valid_1's auc: 0.823041	valid_1's average_precision: 0.155549
# [200]	training's auc: 0.855506	training's average_precision: 0.221662	valid_1's auc: 0.82856	valid_1's average_precision: 0.161005
# [300]	training's auc: 0.866887	training's average_precision: 0.252037	valid_1's auc: 0.830671	valid_1's average_precision: 0.163887
# [400]	training's auc: 0.875981	training's average_precision: 0.28362	valid_1's auc: 0.831503	valid_1's average_precision: 0.164978
# [500]	training's auc: 0.883901	training's average_precision: 0.312711	valid_1's auc: 0.83188	valid_1's average_precision: 0.165672
# [600]	training's auc: 0.890168	training's average_precision: 0.337894	valid_1's auc: 0.832215	valid_1's average_precision: 0.166001
# [700]	training's auc: 0.896674	training's average_precision: 0.36394	valid_1's auc: 0.832228	valid_1's average_precision: 0.166606
# [800]	training's auc: 0.902249	training's average_precision: 0.389168	valid_1's auc: 0.832297	valid_1's average_precision: 0.16654
# Early stopping, best iteration is:
# [772]	training's auc: 0.900946	training's average_precision: 0.382236	valid_1's auc: 0.832434	valid_1's average_precision: 0.166349
# Evaluated only: auc
# Fold 3
# Train: 1221327, Valid: 305332
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.838796	training's average_precision: 0.187826	valid_1's auc: 0.824063	valid_1's average_precision: 0.154462
# [200]	training's auc: 0.85561	training's average_precision: 0.223211	valid_1's auc: 0.830197	valid_1's average_precision: 0.161012
# [300]	training's auc: 0.867213	training's average_precision: 0.254281	valid_1's auc: 0.83255	valid_1's average_precision: 0.163883
# [400]	training's auc: 0.875928	training's average_precision: 0.2829	valid_1's auc: 0.833488	valid_1's average_precision: 0.164851
# [500]	training's auc: 0.883743	training's average_precision: 0.310785	valid_1's auc: 0.834115	valid_1's average_precision: 0.165585
# [600]	training's auc: 0.890777	training's average_precision: 0.338684	valid_1's auc: 0.834458	valid_1's average_precision: 0.166026
# [700]	training's auc: 0.896701	training's average_precision: 0.363925	valid_1's auc: 0.834749	valid_1's average_precision: 0.166482
# [800]	training's auc: 0.902289	training's average_precision: 0.39018	valid_1's auc: 0.835049	valid_1's average_precision: 0.167005
# [900]	training's auc: 0.907869	training's average_precision: 0.415121	valid_1's auc: 0.835025	valid_1's average_precision: 0.167331
# Early stopping, best iteration is:
# [853]	training's auc: 0.905243	training's average_precision: 0.403356	valid_1's auc: 0.83518	valid_1's average_precision: 0.167501
# Evaluated only: auc
# Fold 4
# Train: 1221327, Valid: 305332
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.839318	training's average_precision: 0.188179	valid_1's auc: 0.820835	valid_1's average_precision: 0.152066
# [200]	training's auc: 0.855352	training's average_precision: 0.221995	valid_1's auc: 0.826401	valid_1's average_precision: 0.157996
# [300]	training's auc: 0.867024	training's average_precision: 0.253397	valid_1's auc: 0.828662	valid_1's average_precision: 0.160802
# [400]	training's auc: 0.875969	training's average_precision: 0.283481	valid_1's auc: 0.829846	valid_1's average_precision: 0.161805
# [500]	training's auc: 0.883361	training's average_precision: 0.311195	valid_1's auc: 0.83036	valid_1's average_precision: 0.162881
# [600]	training's auc: 0.890792	training's average_precision: 0.338914	valid_1's auc: 0.830665	valid_1's average_precision: 0.163971
# [700]	training's auc: 0.896986	training's average_precision: 0.364687	valid_1's auc: 0.831039	valid_1's average_precision: 0.164597
# Early stopping, best iteration is:
# [698]	training's auc: 0.896944	training's average_precision: 0.364353	valid_1's auc: 0.831057	valid_1's average_precision: 0.164665
# Evaluated only: auc
# Fold 5
# Train: 1221328, Valid: 305331
# Training until validation scores don't improve for 100 rounds
# [100]	training's auc: 0.838571	training's average_precision: 0.186095	valid_1's auc: 0.823061	valid_1's average_precision: 0.155201
# [200]	training's auc: 0.854534	training's average_precision: 0.220037	valid_1's auc: 0.828531	valid_1's average_precision: 0.161485
# [300]	training's auc: 0.865682	training's average_precision: 0.249629	valid_1's auc: 0.831034	valid_1's average_precision: 0.164597
# [400]	training's auc: 0.87488	training's average_precision: 0.279292	valid_1's auc: 0.832065	valid_1's average_precision: 0.166134
# [500]	training's auc: 0.882407	training's average_precision: 0.306859	valid_1's auc: 0.832554	valid_1's average_precision: 0.167042
# [600]	training's auc: 0.889257	training's average_precision: 0.333177	valid_1's auc: 0.832736	valid_1's average_precision: 0.167587
# [700]	training's auc: 0.895856	training's average_precision: 0.361252	valid_1's auc: 0.83284	valid_1's average_precision: 0.167994
# Early stopping, best iteration is:
# [656]	training's auc: 0.893314	training's average_precision: 0.349695	valid_1's auc: 0.832956	valid_1's average_precision: 0.168122
# Evaluated only: auc

# %%
for i, model in enumerate(models):
    with open(Path.joinpath(PROJECT_PATH, f'model_{i}.pkl'), 'wb') as f:
        pickle.dump(model, f)

# save y_preds_valid
np.save(Path.joinpath(PROJECT_PATH, 'y_preds_valid.npy'), y_preds_valid)
np.save(Path.joinpath(PROJECT_PATH, 'idx_valid.npy'), idx_valid)

# %%
evaluator = data.Evaluator(y.iloc[idx_valid], y_preds_valid, save_path=PROJECT_PATH)

evaluator.plot_pred(is_log=True)
evaluator.plot_roc()
df_gini_weeks, stability = evaluator.plot_gini()
# Out:
# 0.637058514169536
