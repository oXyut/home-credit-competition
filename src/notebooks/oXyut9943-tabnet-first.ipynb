# %%
from collections import OrderedDict
import gc
from pathlib import Path
import pickle
import sys
sys.path.append('..')
from typing import Dict, List, Tuple, Union, Literal, Optional
import warnings
import joblib

import numpy as np
import pandas as pd
import polars as pl
import polars.selectors as cs
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import StratifiedGroupKFold, train_test_split

import torch
from pytorch_tabnet.tab_model import TabNetClassifier
from pytorch_tabnet.pretraining import TabNetPretrainer

gc.enable()
print(torch.__version__)
# Out:
# 2.3.0

# %%
KAGGLE = False
MODE:Literal['train', 'test'] = 'train'
FILL_NA = True
PRE_TRAIN = False

# %%
if KAGGLE:
    COMPETITION_DIR = Path('/kaggle/input/home-credit-credit-risk-model-stability')
    MODEL_DIR = Path('/kaggle/input/240407-home-credit-test-submit')
    FEATURE_DTYPE_DIR = Path('/kaggle/input/home-credit-enhanced-feature-definitions')
else:
    COMPETITION_DIR = Path('../../data/inputs')
    MODEL_DIR = Path('../../data/models/tabnet-first')
    if not MODEL_DIR.exists():
        MODEL_DIR.mkdir(parents=True)
        MODEL_DIR.joinpath('encoders').mkdir()
        print(MODEL_DIR, 'created')
    FEATURE_DTYPE_DIR = Path('../../data/configs/feature_definitions_dtypes_tables.parquet')

# %%
df_features = pd.read_parquet(FEATURE_DTYPE_DIR)
display(df_features)

bool_features = df_features.query('dtype == "Boolean"')
float64_features = df_features.query('dtype == "Float64"')
string_features = df_features.query('dtype == "String"')
date_features = df_features.query('dtype == "Date"')

with warnings.catch_warnings():
    warnings.simplefilter('ignore')
    bool_features['cast_dtype'] = pl.Boolean
    float64_features['cast_dtype'] = pl.Float32
    string_features['cast_dtype'] = pl.String
    date_features['cast_dtype'] = pl.Date

cast_features = pd.concat([bool_features, float64_features, string_features, date_features], ignore_index=True)
display(cast_features)
# Out:
#                      Variable  \
# 0              actualdpd_943P
# 1     actualdpdtolerance_344P
# 2        addres_district_368M
# 3            addres_role_871L
# 4             addres_zip_823M
# ..                        ...
# 460  totinstallast1m_4525188A
# 461        twobodfilling_608L
# 462                  type_25L
# 463            typesuite_864L
# 464           validfrom_1069D
#
#                                            Description    dtype  \
# 0    Days Past Due (DPD) of previous contract (actu...  Float64
# 1                        DPD of client with tolerance.  Float64
# 2                    District of the person's address.   String
# 3                            Role of person's address.   String
# 4                             Zip code of the address.   String
# ..                                                 ...      ...
# 460  Total amount of monthly instalments paid in th...  Float64
# 461                       Type of application process.   String
# 462                          Contact type of a person.   String
# 463  Persons accompanying the client during the loa...   String
# 464      Date since the client has an active campaign.     Date
#
#                                        tables
# 0    [train_applprev_1_0, train_applprev_1_1]
# 1        [train_static_0_0, train_static_0_1]
# 2                            [train_person_2]
# 3                            [train_person_2]
# 4                            [train_person_2]
# ..                                        ...
# 460      [train_static_0_0, train_static_0_1]
# 461      [train_static_0_0, train_static_0_1]
# 462                          [train_person_1]
# 463      [train_static_0_0, train_static_0_1]
# 464      [train_static_0_0, train_static_0_1]
#
# [465 rows x 4 columns]
#                        Variable  \
# 0      contaddr_matchlist_1032L
# 1      contaddr_smempladdr_334L
# 2    equalitydataagreement_891L
# 3           equalityempfrom_62L
# 4            isbidproduct_1095L
# ..                          ...
# 459        refreshdate_3813885D
# 460          responsedate_1012D
# 461       responsedate_4527233D
# 462       responsedate_4917613D
# 463             validfrom_1069D
#
#                                            Description    dtype  \
# 0    Indicates whether the contact address is found...  Boolean
# 1    Indicates whether the contact address is the s...  Boolean
# 2    Flag indicating sudden changes in client's soc...  Boolean
# 3    Flag indicating a sudden change in the client'...  Boolean
# 4      Flag indicating if the product is a cross-sell.  Boolean
# ..                                                 ...      ...
# 459  Date when the credit bureau's public sources h...     Date
# 460                     Tax authority's response date.     Date
# 461                     Tax authority's response date.     Date
# 462                     Tax authority's response date.     Date
# 463      Date since the client has an active campaign.     Date
#
#                                                 tables cast_dtype
# 0                                     [train_person_1]    Boolean
# 1                                     [train_person_1]    Boolean
# 2                 [train_static_0_0, train_static_0_1]    Boolean
# 3                 [train_static_0_0, train_static_0_1]    Boolean
# 4                 [train_static_0_0, train_static_0_1]    Boolean
# ..                                                 ...        ...
# 459  [train_credit_bureau_a_1_0, train_credit_burea...       Date
# 460                                [train_static_cb_0]       Date
# 461                                [train_static_cb_0]       Date
# 462                                [train_static_cb_0]       Date
# 463               [train_static_0_0, train_static_0_1]       Date
#
# [464 rows x 5 columns]

# %%
def get_depth_paths(load_dir: Path, prefix: Literal['test', 'train']):
    
    assert prefix in ['test', 'train']
    
    depth_paths = OrderedDict()

    depth_paths['static_0'] = []
    depth_paths['static_cb_0'] = []
    depth_paths['applprev_1'] = []
    depth_paths['other_1'] = []
    depth_paths['tax_registry_a_1'] = []
    depth_paths['tax_registry_b_1'] = []
    depth_paths['tax_registry_c_1'] = []
    depth_paths['credit_bureau_a_1'] = []
    depth_paths['credit_bureau_b_1'] = []
    depth_paths['deposit_1'] = []
    depth_paths['person_1'] = []
    depth_paths['debitcard_1'] = []
    depth_paths['applprev_2'] = []
    depth_paths['person_2'] = []
    depth_paths['credit_bureau_a_2'] = []
    depth_paths['credit_bureau_b_2'] = []

    for k in depth_paths.keys():
        depth_paths[k] = sorted(
            [p for p in load_dir.joinpath(f'parquet_files/{prefix}').glob(f'{prefix}_{k}*.parquet')]
        )
    return depth_paths

# %%
depth_paths = get_depth_paths(COMPETITION_DIR, MODE)

print(f'the number of {MODE} paths: {sum(len(v1) for v1 in depth_paths.values())}')
# Out:
# the number of train paths: 31

# %%
def process_D_features(data: pl.DataFrame, D_columns: List[str]):
    for col in D_columns:
        # 1. convert to datetime from string
        # 2. add y, m, d, wd columns
        # 3. delete original column
        data = data.with_columns([
            pl.col(col).str_to_datetime(format='%Y-%m-%d', errors='coerce').alias(col)
        ])
        data = data.with_columns([
            pl.col(col).year().alias(f'y_{col}'),
            pl.col(col).month().alias(f'm_{col}'),
            pl.col(col).day().alias(f'd_{col}'),
            pl.col(col).weekday().alias(f'wd_{col}')
        ])
        data.drop_in_place(col)
    return data

def process_date_features(data: pl.DataFrame) -> pl.DataFrame:
    data = data.with_columns(
        pl.col(pl.Date).dt.year().cast(pl.Float32).name.prefix('year_'),
        pl.col(pl.Date).dt.month().cast(pl.Float32).name.prefix('month_'),
        pl.col(pl.Date).dt.day().cast(pl.Float32).name.prefix('day_'),
    )
    data = data.drop(cs.date())
    return data

# %%
def merge_dataset(
        base_data: pl.DataFrame,
        depth_paths: Dict[str, List[Path]],
        bool_features: pd.DataFrame,
        float64_features: pd.DataFrame,
        string_features: pd.DataFrame,
        depth: Literal['0', '1', '2', '012'],
    ) -> pd.DataFrame:
    
    assert depth in ['0', '1', '2', '012']
    
    for i, (k, path_list) in enumerate(depth_paths.items()):
        
        if depth == '012':
            pass
        elif depth != k[-1]:
            continue
            
        print(f'loading `{k}`')
        depth_data = []
        for p in path_list:
            sub_data = pl.read_parquet(p).cast({'case_id': pl.Int64})
            if k[-1] == '1':
                sub_data = sub_data.drop('num_group1').group_by('case_id').max().sort('case_id')
            elif k[-1] == '2':
                sub_data = sub_data.drop(['num_group1', 'num_group2']).group_by('case_id').max().sort('case_id')
                
            depth_data.append(sub_data)
            
            print(f'\t{p.stem}: {sub_data.shape}')
            
            del sub_data
            gc.collect()
        
        depth_data = pl.concat(depth_data, how='vertical_relaxed')
        base_data = base_data.join(depth_data, how='left', on='case_id', suffix=f'_{i}')
        
        del depth_data
        gc.collect()
    
    '''
    cast dtypes
    '''
    for _, row in bool_features[['Variable', 'cast_dtype']].iterrows():
        col = row['Variable']
        cast_dtype = row['cast_dtype']
        if col in base_data.columns:
            base_data = base_data.with_columns(pl.col(col).fill_null(np.nan).cast(cast_dtype))
        
    for _, row in float64_features[['Variable', 'cast_dtype']].iterrows():
        col = row['Variable']
        cast_dtype = row['cast_dtype']
        if col in base_data.columns:
            base_data = base_data.with_columns(pl.col(col).cast(cast_dtype))
            
    for _, row in string_features[['Variable', 'cast_dtype']].iterrows():
        col = row['Variable']
        cast_dtype = row['cast_dtype']
        if col in base_data.columns:
            base_data = base_data.with_columns(pl.col(col).cast(cast_dtype))
    
    '''
    process D features
    '''
    D_features = [col for col in base_data.columns if col[-1] == 'D']
    # base_data = process_D_features(base_data, D_features)
    base_data = process_date_features(base_data)
    base_data = base_data.to_pandas()
    return base_data


def encode(depth_data:pd.DataFrame, mode:Literal['train', 'test'], save_dir:Path) -> pd.DataFrame:

    assert mode in ['train', 'test']

    object_columns = depth_data.dtypes.index[depth_data.dtypes==object].to_list()
    if 'date_decision' in object_columns:
        object_columns.remove('date_decision')

    if mode == 'train':
        object_data = []
        print(f'num of object columns: {len(object_columns)}')
        for col in object_columns:
            encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
            encoder.fit(depth_data[col].values.reshape(-1, 1))
            # save encoder as joblib
            save_path = save_dir.joinpath(f'encoder_{col}.joblib')
            joblib.dump(encoder, save_path)
            object_data.append(encoder.transform(depth_data[col].values.reshape(-1, 1)).astype(np.float32))
        depth_data.drop(columns=object_columns, inplace=True)
        print(f'num of object columns: {len(object_data)}')
        object_data = np.concatenate(object_data, axis=1)
        object_data = pd.DataFrame(object_data, columns=object_columns)
    else:
        object_data = []
        for col in object_columns:
            # load encoder
            load_path = save_dir.joinpath(f'encoder_{col}.joblib')
            encoder = joblib.load(load_path)
            object_data.append(encoder.transform(depth_data[col].values.reshape(-1, 1)).astype(np.float32))
        depth_data.drop(columns=object_columns, inplace=True)
        object_data = np.concatenate(object_data, axis=1)
        object_data = pd.DataFrame(object_data, columns=object_columns)

    return pd.concat([depth_data, object_data], axis=1)

# %%
base_data = pl.read_parquet(
    COMPETITION_DIR.joinpath(f'parquet_files/{MODE}/{MODE}_base.parquet')
).cast(
    {
        'case_id': pl.Int64,
        'date_decision': pl.String,
        'MONTH': pl.Int64,
        'WEEK_NUM': pl.Int64,
    }
)

print(MODE)
display(base_data)
# Out:
# train
# shape: (1_526_659, 5)
# ┌─────────┬───────────────┬────────┬──────────┬────────┐
# │ case_id ┆ date_decision ┆ MONTH  ┆ WEEK_NUM ┆ target │
# │ ---     ┆ ---           ┆ ---    ┆ ---      ┆ ---    │
# │ i64     ┆ str           ┆ i64    ┆ i64      ┆ i64    │
# ╞═════════╪═══════════════╪════════╪══════════╪════════╡
# │ 0       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 1       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 2       ┆ 2019-01-04    ┆ 201901 ┆ 0        ┆ 0      │
# │ 3       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 4       ┆ 2019-01-04    ┆ 201901 ┆ 0        ┆ 1      │
# │ …       ┆ …             ┆ …      ┆ …        ┆ …      │
# │ 2703450 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703451 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703452 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703453 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703454 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# └─────────┴───────────────┴────────┴──────────┴────────┘

# %%
depth_data = merge_dataset(
    base_data,
    depth_paths,
    bool_features,
    float64_features,
    string_features,
    '012'
)
display(depth_data)
# Out:
# loading `static_0`
# 	train_static_0_0: (1003757, 168)
# 	train_static_0_1: (522902, 168)
# loading `static_cb_0`
# 	train_static_cb_0: (1500476, 53)
# loading `applprev_1`
# 	train_applprev_1_0: (782997, 40)
# 	train_applprev_1_1: (438525, 40)
# loading `other_1`
# 	train_other_1: (51109, 6)
# loading `tax_registry_a_1`
# 	train_tax_registry_a_1: (457934, 4)
# loading `tax_registry_b_1`
# 	train_tax_registry_b_1: (150732, 4)
# loading `tax_registry_c_1`
# 	train_tax_registry_c_1: (482265, 4)
# loading `credit_bureau_a_1`
# 	train_credit_bureau_a_1_0: (335275, 78)
# 	train_credit_bureau_a_1_1: (549263, 78)
# 	train_credit_bureau_a_1_2: (325127, 78)
# 	train_credit_bureau_a_1_3: (176608, 78)
# loading `credit_bureau_b_1`
# 	train_credit_bureau_b_1: (36500, 44)
# loading `deposit_1`
# 	train_deposit_1: (105111, 4)
# loading `person_1`
# 	train_person_1: (1526659, 36)
# loading `debitcard_1`
# 	train_debitcard_1: (111772, 5)
# loading `applprev_2`
# 	train_applprev_2: (1221522, 4)
# loading `person_2`
# 	train_person_2: (1435105, 9)
# loading `credit_bureau_a_2`
# 	train_credit_bureau_a_2_0: (98303, 17)
# 	train_credit_bureau_a_2_1: (118481, 17)
# 	train_credit_bureau_a_2_10: (23734, 17)
# 	train_credit_bureau_a_2_2: (156749, 17)
# 	train_credit_bureau_a_2_3: (190486, 17)
# 	train_credit_bureau_a_2_4: (190313, 17)
# 	train_credit_bureau_a_2_5: (231250, 17)
# 	train_credit_bureau_a_2_6: (150426, 17)
# 	train_credit_bureau_a_2_7: (45056, 17)
# 	train_credit_bureau_a_2_8: (77457, 17)
# 	train_credit_bureau_a_2_9: (103033, 17)
# loading `credit_bureau_b_2`
# 	train_credit_bureau_b_2: (36447, 4)
#          case_id date_decision   MONTH  WEEK_NUM  target  \
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 1526654                      0.0                   176561.359375
# 1526655                      0.0                   301276.468750
# 1526656                      0.0                    14232.400391
# 1526657                      0.0                   197371.578125
# 1526658                      0.0                    82949.601562
#
#          annuity_780A  annuitynextmonth_57A  applicationcnt_361L  ...  \
# 0         1917.599976              0.000000                  0.0  ...
# 1         3134.000000              0.000000                  0.0  ...
# 2         4937.000000              0.000000                  0.0  ...
# 3         4643.600098              0.000000                  0.0  ...
# 4         3390.199951              0.000000                  0.0  ...
# ...               ...                   ...                  ...  ...
# 1526654   3675.400146              0.000000                  0.0  ...
# 1526655   7088.600098           6191.600098                  0.0  ...
# 1526656   7788.800293              0.000000                  0.0  ...
# 1526657   1195.400024           2827.199951                  0.0  ...
# 1526658   4533.800293           2986.800049                  0.0  ...
#
#          pmts_month_706T  pmts_overdue_1140A  pmts_overdue_1152A  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 1526654             12.0             0.00000         4316.439941
# 1526655             12.0             0.00000            0.000000
# 1526656             12.0          4884.29834            0.000000
# 1526657             12.0             0.00000         2693.199951
# 1526658             12.0             0.00000         4875.020020
#
#          pmts_year_1139T  pmts_year_507T  subjectroles_name_541M  \
# 0                    NaN             NaN                    None
# 1                    NaN             NaN                    None
# 2                    NaN             NaN                    None
# 3                    NaN             NaN                    None
# 4                    NaN             NaN                    None
# ...                  ...             ...                     ...
# 1526654           2021.0          2021.0                ab3c25cf
# 1526655           2021.0          2021.0                ab3c25cf
# 1526656           2021.0          2020.0                ab3c25cf
# 1526657           2021.0          2020.0                ab3c25cf
# 1526658           2021.0          2021.0                ab3c25cf
#
#          subjectroles_name_838M  pmts_date_1107D  pmts_dpdvalue_108P  \
# 0                          None             None                 NaN
# 1                          None             None                 NaN
# 2                          None             None                 NaN
# 3                          None             None                 NaN
# 4                          None             None                 NaN
# ...                         ...              ...                 ...
# 1526654                ab3c25cf             None                 NaN
# 1526655                ab3c25cf             None                 NaN
# 1526656                ab3c25cf             None                 NaN
# 1526657                ab3c25cf             None                 NaN
# 1526658                ab3c25cf             None                 NaN
#
#          pmts_pmtsoverdue_635A
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ...                        ...
# 1526654                    NaN
# 1526655                    NaN
# 1526656                    NaN
# 1526657                    NaN
# 1526658                    NaN
#
# [1526659 rows x 469 columns]

# %%
depth_data = encode(depth_data, MODE, MODEL_DIR.joinpath('encoders'))
display(depth_data)
# Out:
# num of object columns: 156
# num of object columns: 156
#          case_id date_decision   MONTH  WEEK_NUM  target  \
# 0              0    2019-01-03  201901         0       0
# 1              1    2019-01-03  201901         0       0
# 2              2    2019-01-04  201901         0       0
# 3              3    2019-01-03  201901         0       0
# 4              4    2019-01-04  201901         0       1
# ...          ...           ...     ...       ...     ...
# 1526654  2703450    2020-10-05  202010        91       0
# 1526655  2703451    2020-10-05  202010        91       0
# 1526656  2703452    2020-10-05  202010        91       0
# 1526657  2703453    2020-10-05  202010        91       0
# 1526658  2703454    2020-10-05  202010        91       0
#
#          actualdpdtolerance_344P  amtinstpaidbefduel24m_4187115A  \
# 0                            NaN                             NaN
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             NaN
# ...                          ...                             ...
# 1526654                      0.0                   176561.359375
# 1526655                      0.0                   301276.468750
# 1526656                      0.0                    14232.400391
# 1526657                      0.0                   197371.578125
# 1526658                      0.0                    82949.601562
#
#          annuity_780A  annuitynextmonth_57A  applicationcnt_361L  ...  \
# 0         1917.599976              0.000000                  0.0  ...
# 1         3134.000000              0.000000                  0.0  ...
# 2         4937.000000              0.000000                  0.0  ...
# 3         4643.600098              0.000000                  0.0  ...
# 4         3390.199951              0.000000                  0.0  ...
# ...               ...                   ...                  ...  ...
# 1526654   3675.400146              0.000000                  0.0  ...
# 1526655   7088.600098           6191.600098                  0.0  ...
# 1526656   7788.800293              0.000000                  0.0  ...
# 1526657   1195.400024           2827.199951                  0.0  ...
# 1526658   4533.800293           2986.800049                  0.0  ...
#
#          empls_employedfrom_796D  empls_employer_name_740M  \
# 0                          801.0                       1.0
# 1                          801.0                       1.0
# 2                          801.0                       1.0
# 3                          801.0                       1.0
# 4                          801.0                       1.0
# ...                          ...                       ...
# 1526654                    801.0                       0.0
# 1526655                    801.0                       0.0
# 1526656                    801.0                       0.0
# 1526657                    801.0                       0.0
# 1526658                    801.0                       0.0
#
#          relatedpersons_role_762T  collater_typofvalofguarant_298M  \
# 0                            10.0                              2.0
# 1                            10.0                              2.0
# 2                            10.0                              2.0
# 3                            10.0                              2.0
# 4                            10.0                              2.0
# ...                           ...                              ...
# 1526654                      10.0                              1.0
# 1526655                      10.0                              1.0
# 1526656                      10.0                              1.0
# 1526657                      10.0                              1.0
# 1526658                      10.0                              1.0
#
#          collater_typofvalofguarant_407M  collaterals_typeofguarante_359M  \
# 0                                    5.0                              5.0
# 1                                    5.0                              5.0
# 2                                    5.0                              5.0
# 3                                    5.0                              5.0
# 4                                    5.0                              5.0
# ...                                  ...                              ...
# 1526654                              2.0                              3.0
# 1526655                              2.0                              3.0
# 1526656                              2.0                              3.0
# 1526657                              2.0                              3.0
# 1526658                              2.0                              3.0
#
#          collaterals_typeofguarante_669M  subjectroles_name_541M  \
# 0                                    5.0                     4.0
# 1                                    5.0                     4.0
# 2                                    5.0                     4.0
# 3                                    5.0                     4.0
# 4                                    5.0                     4.0
# ...                                  ...                     ...
# 1526654                              3.0                     1.0
# 1526655                              3.0                     1.0
# 1526656                              3.0                     1.0
# 1526657                              3.0                     1.0
# 1526658                              3.0                     1.0
#
#          subjectroles_name_838M  pmts_date_1107D
# 0                           4.0             27.0
# 1                           4.0             27.0
# 2                           4.0             27.0
# 3                           4.0             27.0
# 4                           4.0             27.0
# ...                         ...              ...
# 1526654                     1.0             27.0
# 1526655                     1.0             27.0
# 1526656                     1.0             27.0
# 1526657                     1.0             27.0
# 1526658                     1.0             27.0
#
# [1526659 rows x 469 columns]

# %%
# cut columns where NaN ratio is over 0.5
# nan_ratio = depth_data.isnull().mean()
# cut_columns = nan_ratio[nan_ratio > 0.5].index
# depth_data.drop(columns=cut_columns, inplace=True)

# display(depth_data)

# # save cut_columns
# with open(MODEL_DIR.joinpath('cut_columns.pkl'), 'wb') as f:
#     pickle.dump(cut_columns, f)


# # load cut_columns
# with open(MODEL_DIR.joinpath('cut_columns.pkl'), 'rb') as f:
#     cut_columns = pickle.load(f)

# %%
if MODE == 'train':
    X, y= (
        depth_data.drop(columns=['case_id', 'target', 'date_decision']),
        depth_data[['case_id', 'target', 'WEEK_NUM']],
    )
else:
    X = depth_data.drop(columns=['case_id', 'date_decision'])
    y = depth_data[['case_id', 'WEEK_NUM']]

# %%
X.dtypes.value_counts()
# Out:
# float32    451
# bool        13
# int64        2
# Name: count, dtype: int64

# %%
if FILL_NA:
    X.fillna(-999, inplace=True)
    assert X.isnull().sum().sum() == 0

# %%
params = dict(
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=2e-2),
)

# %%
def pre_train(X: pd.DataFrame, params: dict):
    X_train, X_valid = train_test_split(X, test_size=0.2, random_state=42)
    pretrainer = TabNetPretrainer(
        **params
    )
    X_train = X_train.values.astype(np.float32)
    X_valid = X_valid.values.astype(np.float32)
    
    pretrainer.fit(
        X_train=X_train,
        eval_set=[X_train, X_valid],
        max_epochs=100,
        patience=10,
        batch_size=1024,
        virtual_batch_size=128,
        num_workers=0,
        pretraining_ratio=0.8,
    )
    
    return pretrainer

def train(X: pd.DataFrame, y: pd.DataFrame, params:dict, pretrainer:Optional[TabNetPretrainer]=None):
    n_splits = 5
    skf = StratifiedGroupKFold(n_splits=n_splits, shuffle=True, random_state=42)
    models = []
    oof = np.zeros((X.shape[0], 2))

    for fold, (train_idx, valid_idx) in enumerate(skf.split(X, y['target'], y['WEEK_NUM'])):
        print(f'fold: {fold}')
        X_train, X_valid = X.iloc[train_idx], X.iloc[valid_idx]
        y_train, y_valid = y.iloc[train_idx], y.iloc[valid_idx]

        X_train, X_valid = X_train.values.astype(np.float32), X_valid.values.astype(np.float32)
        y_train, y_valid = y_train['target'].values, y_valid['target'].values

        print(X_train.shape, y_train.shape)
        print(X_train.dtype, y_train.dtype)

        model = TabNetClassifier(**params)
        model.fit(
            X_train=X_train,
            y_train=y_train,
            eval_set=[(X_train, y_train), (X_valid, y_valid)],
            eval_name=['train', 'valid'],
            eval_metric=['logloss', 'accuracy'],
            max_epochs=100,
            patience=10,
            batch_size=512,
            virtual_batch_size=128,
            num_workers=0,
            drop_last=False,
            from_unsupervised=pretrainer
        )

        models.append(model)
        oof[valid_idx] = model.predict_proba(X_valid)

        model_path = MODEL_DIR.joinpath(f'model_{fold}')
        model.save_model(str(model_path))

        gc.collect()

    return models, oof

# %%
if MODE == 'train':
    pretrainer = pre_train(X, params) if PRE_TRAIN else None
    models, oof = train(X, y, params, pretrainer)
    oof = pd.DataFrame(oof, columns=['oof_0', 'oof_1'])
    oof['case_id'] = y['case_id']
    oof.to_csv(MODEL_DIR.joinpath('oof.csv'), index=False)
    display(oof)
else:
    pass
# Out:
# fold: 0
# (1202502, 466) (1202502,)
# float32 int64
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.14023 | train_logloss: 0.1377  | train_accuracy: 0.96841 | valid_logloss: 0.13526 | valid_accuracy: 0.96911 |  0:03:59s
# epoch 1  | loss: 0.13292 | train_logloss: 0.12414 | train_accuracy: 0.96841 | valid_logloss: 0.12091 | valid_accuracy: 0.96911 |  0:07:57s
# epoch 2  | loss: 0.12302 | train_logloss: 0.12229 | train_accuracy: 0.96841 | valid_logloss: 0.11911 | valid_accuracy: 0.96911 |  0:11:55s
# epoch 3  | loss: 0.12039 | train_logloss: 0.11977 | train_accuracy: 0.96841 | valid_logloss: 0.11774 | valid_accuracy: 0.96911 |  0:15:55s
# epoch 4  | loss: 0.11946 | train_logloss: 0.12094 | train_accuracy: 0.96841 | valid_logloss: 0.1178  | valid_accuracy: 0.96911 |  0:19:54s
# epoch 5  | loss: 0.11889 | train_logloss: 0.11957 | train_accuracy: 0.96841 | valid_logloss: 0.11649 | valid_accuracy: 0.96911 |  0:23:55s
# epoch 6  | loss: 0.11843 | train_logloss: 0.11857 | train_accuracy: 0.96841 | valid_logloss: 0.11613 | valid_accuracy: 0.96911 |  0:27:58s
# epoch 7  | loss: 0.11839 | train_logloss: 0.11739 | train_accuracy: 0.96841 | valid_logloss: 0.11476 | valid_accuracy: 0.96911 |  0:32:03s
# epoch 8  | loss: 0.11836 | train_logloss: 0.11821 | train_accuracy: 0.96841 | valid_logloss: 0.11597 | valid_accuracy: 0.96911 |  0:36:06s
# epoch 9  | loss: 0.11776 | train_logloss: 0.11814 | train_accuracy: 0.96841 | valid_logloss: 0.11566 | valid_accuracy: 0.96911 |  0:40:09s
# epoch 10 | loss: 0.11752 | train_logloss: 0.11937 | train_accuracy: 0.96841 | valid_logloss: 0.11685 | valid_accuracy: 0.96911 |  0:44:12s
#
# Early stopping occurred at epoch 10 with best_epoch = 0 and best_valid_accuracy = 0.96911
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Successfully saved model at ../../data/models/tabnet-first/model_0.zip
# fold: 1
# (1201472, 466) (1201472,)
# float32 int64
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.13466 | train_logloss: 0.12737 | train_accuracy: 0.96787 | valid_logloss: 0.11792 | valid_accuracy: 0.97112 |  0:04:04s
# epoch 1  | loss: 0.12386 | train_logloss: 0.12228 | train_accuracy: 0.96787 | valid_logloss: 0.11431 | valid_accuracy: 0.97112 |  0:08:10s
# epoch 2  | loss: 0.12099 | train_logloss: 0.12007 | train_accuracy: 0.96787 | valid_logloss: 0.11225 | valid_accuracy: 0.97112 |  0:12:18s
# epoch 3  | loss: 0.11996 | train_logloss: 0.11896 | train_accuracy: 0.96787 | valid_logloss: 0.1115  | valid_accuracy: 0.97112 |  0:16:23s
# epoch 4  | loss: 0.11933 | train_logloss: 0.11875 | train_accuracy: 0.96787 | valid_logloss: 0.11146 | valid_accuracy: 0.97112 |  0:20:25s
# epoch 5  | loss: 0.11887 | train_logloss: 0.11937 | train_accuracy: 0.96787 | valid_logloss: 0.11232 | valid_accuracy: 0.97112 |  0:24:29s
# epoch 6  | loss: 0.11849 | train_logloss: 0.11891 | train_accuracy: 0.96787 | valid_logloss: 0.11175 | valid_accuracy: 0.97112 |  0:28:33s
# epoch 7  | loss: 0.11796 | train_logloss: 0.11857 | train_accuracy: 0.96787 | valid_logloss: 0.11146 | valid_accuracy: 0.97112 |  1:02:54s
# epoch 8  | loss: 0.11776 | train_logloss: 0.11756 | train_accuracy: 0.96787 | valid_logloss: 0.11132 | valid_accuracy: 0.97111 |  3:35:35s
# epoch 9  | loss: 0.11749 | train_logloss: 0.11857 | train_accuracy: 0.96787 | valid_logloss: 0.11199 | valid_accuracy: 0.97112 |  3:42:36s
# epoch 10 | loss: 0.11713 | train_logloss: 0.11798 | train_accuracy: 0.96787 | valid_logloss: 0.11143 | valid_accuracy: 0.97112 |  3:46:46s
#
# Early stopping occurred at epoch 10 with best_epoch = 0 and best_valid_accuracy = 0.97112
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# Successfully saved model at ../../data/models/tabnet-first/model_1.zip
# fold: 2
# (1229154, 466) (1229154,)
# float32 int64
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# epoch 0  | loss: 0.13013 | train_logloss: 0.12068 | train_accuracy: 0.96917 | valid_logloss: 0.12981 | valid_accuracy: 0.96606 |  0:04:05s
# epoch 1  | loss: 0.1196  | train_logloss: 0.11837 | train_accuracy: 0.96917 | valid_logloss: 0.12761 | valid_accuracy: 0.96606 |  0:08:17s
# epoch 2  | loss: 0.11891 | train_logloss: 0.119   | train_accuracy: 0.96917 | valid_logloss: 0.1283  | valid_accuracy: 0.96606 |  0:12:30s
# epoch 3  | loss: 0.11849 | train_logloss: 0.11965 | train_accuracy: 0.96917 | valid_logloss: 0.12841 | valid_accuracy: 0.96606 |  0:16:37s
# epoch 4  | loss: 0.11721 | train_logloss: 0.11646 | train_accuracy: 0.96917 | valid_logloss: 0.12559 | valid_accuracy: 0.96606 |  0:20:45s
# epoch 5  | loss: 0.11661 | train_logloss: 0.1187  | train_accuracy: 0.96917 | valid_logloss: 0.12921 | valid_accuracy: 0.96606 |  0:24:52s
# epoch 6  | loss: 0.11632 | train_logloss: 0.11673 | train_accuracy: 0.96917 | valid_logloss: 0.12681 | valid_accuracy: 0.96606 |  0:29:01s
# epoch 7  | loss: 0.1169  | train_logloss: 0.11635 | train_accuracy: 0.96917 | valid_logloss: 0.1255  | valid_accuracy: 0.96606 |  0:33:10s
# epoch 8  | loss: 0.11636 | train_logloss: 0.12472 | train_accuracy: 0.96913 | valid_logloss: 0.13689 | valid_accuracy: 0.966   |  0:37:36s
# epoch 9  | loss: 0.11553 | train_logloss: 0.12584 | train_accuracy: 0.96915 | valid_logloss: 0.13743 | valid_accuracy: 0.96603 |  0:41:44s
# epoch 10 | loss: 0.11589 | train_logloss: 0.11589 | train_accuracy: 0.96911 | valid_logloss: 0.12588 | valid_accuracy: 0.96598 |  4:06:57s
#
# Early stopping occurred at epoch 10 with best_epoch = 0 and best_valid_accuracy = 0.96606
# /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 if MODE == 'train':
#       2     pretrainer = pre_train(X, params) if PRE_TRAIN else None
# ----> 3     models, oof = train(X, y, params, pretrainer)
#       4     oof = pd.DataFrame(oof, columns=['oof_0', 'oof_1'])
#       5     oof['case_id'] = y['case_id']
#
# Cell In[17], line 40, in train(X, y, params, pretrainer)
#      37 print(X_train.dtype, y_train.dtype)
#      39 model = TabNetClassifier(**params)
# ---> 40 model.fit(
#      41     X_train=X_train,
#      42     y_train=y_train,
#      43     eval_set=[(X_train, y_train), (X_valid, y_valid)],
#      44     eval_name=['train', 'valid'],
#      45     eval_metric=['logloss', 'accuracy'],
#      46     max_epochs=100,
#      47     patience=10,
#      48     batch_size=512,
#      49     virtual_batch_size=128,
#      50     num_workers=0,
#      51     drop_last=False,
#      52     from_unsupervised=pretrainer
#      53 )
#      55 models.append(model)
#      56 oof[valid_idx] = model.predict_proba(X_valid)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:278, in TabModel.fit(self, X_train, y_train, eval_set, eval_name, eval_metric, loss_fn, weights, max_epochs, patience, batch_size, virtual_batch_size, num_workers, drop_last, callbacks, pin_memory, from_unsupervised, warm_start, augmentations, compute_importance)
#     274 self.network.eval()
#     276 if self.compute_importance:
#     277     # compute feature importance once the best model is defined
# --> 278     self.feature_importances_ = self._compute_feature_importances(X_train)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:759, in TabModel._compute_feature_importances(self, X)
#     750 def _compute_feature_importances(self, X):
#     751     """Compute global feature importance.
#     752
#     753     Parameters
#    (...)
#     757
#     758     """
# --> 759     M_explain, _ = self.explain(X, normalize=False)
#     760     sum_explain = M_explain.sum(axis=0)
#     761     feature_importances_ = sum_explain / np.sum(sum_explain)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/pytorch_tabnet/abstract_model.py:369, in TabModel.explain(self, X, normalize)
#     367     else:
#     368         for key, value in masks.items():
# --> 369             res_masks[key] = np.vstack([res_masks[key], value])
#     371 res_explain = np.vstack(res_explain)
#     373 if normalize:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/kaggle-tabnet/lib/python3.10/site-packages/numpy/core/shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# KeyboardInterrupt:
